# %%
import requests

url = "https://google-translator9.p.rapidapi.com/v2"
ask=input("Enter something here")
lng=input("In which language you want to convert \n hi For Hindi ar for arbian")
mydata = {
	"q": ask,
    "source": "en",
	"target": lng,
	"format": "text"
}
headers = {
	"x-rapidapi-key": "3ee8981cedmsh93421ad73062b55p1c6cf9jsnc5b5126b7e87",
	"x-rapidapi-host": "google-translator9.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.post(url, json=mydata, headers=headers)

result = response.json()


print(result['data']['translations'][0]['translatedText'])
# Out:
# Enter something here i am a jyoti
# In which language you want to convert
#  hi For Hindi ar for arbian hi
# मैं एक ज्योति हूं
